# %%
import numpy as np
import pandas as pd
from dataset_management import parse_traces


trace = 'VoD-SingleApp-PeriodicLoad'
y_metric = 'noAudioPlayed'

x, y_audio = parse_traces(trace, y_metric, ['X_cluster.csv', 'X_flow.csv', 'X_port.csv'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.title('Métrica noAudioPlayed')
plt.ylabel('Frequência')

sns.histplot(y_audio, bins=25, kde=False)
plt.show()

# %%
import numpy as np
import pandas as pd
from dataset_management import parse_traces


trace = 'VoD-SingleApp-PeriodicLoad'
y_metric = 'DispFrames'

x, y_video = parse_traces(trace, y_metric, ['X_cluster.csv', 'X_flow.csv', 'X_port.csv'])

# %%
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
import numpy as np

from matplotlib.ticker import FuncFormatter

plt.title('Quadros por Segundo - VoD - Uma Aplicação - Carga Periódica')
plt.ylabel('Densidade')

sns.kdeplot(y_video)
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:.0%}'.format(y)))
plt.show()

# %%
(y_video).mean()

# %%
import numpy as np
import pandas as pd
from dataset_management import parse_traces


trace = 'VoD-SingleApp-FlashcrowdLoad'
y_metric = 'DispFrames'

x, y_video = parse_traces(trace, y_metric, ['X_cluster.csv', 'X_flow.csv', 'X_port.csv'])

# %%
(y_video < 24).sum()/len(y_video)
# Out:
# DispFrames    0.200994
# dtype: float64

# %%
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
import numpy as np

from matplotlib.ticker import FuncFormatter

plt.title('Métrica DispFrames')
plt.ylabel('Densidade')

sns.histplot(y_video, bins=25, kde=False)
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:.0%}'.format(y)))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 10
#       7 plt.title('Métrica DispFrames')
#       8 plt.ylabel('Densidade')
# ---> 10 sns.histplot(y_video, bins=25, kde=False)
#      11 plt.show()
#
# NameError: name 'y_video' is not defined

# %%
import numpy as np
import pandas as pd
from dataset_management import parse_traces


trace = 'KV-SingleApp-PeriodicLoad'
y_metric = 'ReadsAvg'

x_db, y_db = parse_traces(trace, y_metric, ['X_cluster.csv', 'X_flow.csv', 'X_port.csv'])

# %%
y_db.shape
# Out:
# (28962, 1)

# %%
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
import numpy as np

plt.title('Métrica ReadsAvg')
plt.ylabel('Densidade')

sns.kdeplot(y_db)
plt.show()
