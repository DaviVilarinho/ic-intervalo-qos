# %%
import pandas as pd
univariate_results = pd.read_csv('univariate_experiment/2023-10-28T15:32:10/table_iv.csv', index_col=0)

# %%
k_best_means = univariate_results.groupby('k_best').mean(1)

import matplotlib.pyplot as plt

figure, axis = plt.subplots(2, 1) 

axis[0].plot(k_best_means['ReadsAvgNmae']) # então a partir de 8 não faz muita diferença...
axis[1].plot(k_best_means['DispFramesNmae']) # então a partir de 8 não faz muita diferença...
plt.show()
