# %%
import pandas as pd
import numpy as np

subpath = "distrib_tptt_experiment_y_original_fs_multiplied/2025-01-26T16:32:01"
data = pd.read_csv(f'{subpath}/minimal_with_univariate.csv', index_col=False)

# %%
data
# Out:
#     período           carga       apps     feature método      nmae
# 0       256  FlashcrowdLoad   BothApps  DispFrames     RT  0.262295
# 1       256  FlashcrowdLoad   BothApps  DispFrames     RF  0.226391
# 2       128  FlashcrowdLoad   BothApps  DispFrames     RT  0.080902
# 3       128  FlashcrowdLoad   BothApps  DispFrames     RF  0.083234
# 4        64  FlashcrowdLoad   BothApps  DispFrames     RT  0.123461
# 5        64  FlashcrowdLoad   BothApps  DispFrames     RF  0.116527
# 6        32  FlashcrowdLoad   BothApps  DispFrames     RT  0.120837
# 7        32  FlashcrowdLoad   BothApps  DispFrames     RF  0.118618
# 8        16  FlashcrowdLoad   BothApps  DispFrames     RT  0.098498
# 9        16  FlashcrowdLoad   BothApps  DispFrames     RF  0.101019
# 10        8  FlashcrowdLoad   BothApps  DispFrames     RT  0.079133
# 11        8  FlashcrowdLoad   BothApps  DispFrames     RF  0.082289
# 12      256    PeriodicLoad   BothApps  DispFrames     RT  0.117385
# 13      256    PeriodicLoad   BothApps  DispFrames     RF  0.161999
# 14      128    PeriodicLoad   BothApps  DispFrames     RT  0.193787
# 15      128    PeriodicLoad   BothApps  DispFrames     RF  0.164294
# 16       64    PeriodicLoad   BothApps  DispFrames     RT  0.120585
# 17       64    PeriodicLoad   BothApps  DispFrames     RF  0.117686
# 18       32    PeriodicLoad   BothApps  DispFrames     RT  0.162562
# 19       32    PeriodicLoad   BothApps  DispFrames     RF  0.152293
# 20       16    PeriodicLoad   BothApps  DispFrames     RT  0.142275
# 21       16    PeriodicLoad   BothApps  DispFrames     RF  0.140353
# 22        8    PeriodicLoad   BothApps  DispFrames     RT  0.122951
# 23        8    PeriodicLoad   BothApps  DispFrames     RF  0.124763
# 24      256  FlashcrowdLoad  SingleApp  DispFrames     RT  0.165953
# 25      256  FlashcrowdLoad  SingleApp  DispFrames     RF  0.151062
# 26      128  FlashcrowdLoad  SingleApp  DispFrames     RT  0.192522
# 27      128  FlashcrowdLoad  SingleApp  DispFrames     RF  0.188718
# 28       64  FlashcrowdLoad  SingleApp  DispFrames     RT  0.136685
# 29       64  FlashcrowdLoad  SingleApp  DispFrames     RF  0.136114
# 30       32  FlashcrowdLoad  SingleApp  DispFrames     RT  0.103741
# 31       32  FlashcrowdLoad  SingleApp  DispFrames     RF  0.102731
# 32       16  FlashcrowdLoad  SingleApp  DispFrames     RT  0.100678
# 33       16  FlashcrowdLoad  SingleApp  DispFrames     RF  0.096233
# 34        8  FlashcrowdLoad  SingleApp  DispFrames     RT  0.082914
# 35        8  FlashcrowdLoad  SingleApp  DispFrames     RF  0.083697
# 36      256    PeriodicLoad  SingleApp  DispFrames     RT  0.065126
# 37      256    PeriodicLoad  SingleApp  DispFrames     RF  0.077845
# 38      128    PeriodicLoad  SingleApp  DispFrames     RT  0.071905
# 39      128    PeriodicLoad  SingleApp  DispFrames     RF  0.090139
# 40       64    PeriodicLoad  SingleApp  DispFrames     RT  0.108775
# 41       64    PeriodicLoad  SingleApp  DispFrames     RF  0.103280
# 42       32    PeriodicLoad  SingleApp  DispFrames     RT  0.093665
# 43       32    PeriodicLoad  SingleApp  DispFrames     RF  0.089167
# 44       16    PeriodicLoad  SingleApp  DispFrames     RT  0.095824
# 45       16    PeriodicLoad  SingleApp  DispFrames     RF  0.094894
# 46        8    PeriodicLoad  SingleApp  DispFrames     RT  0.083963
# 47        8    PeriodicLoad  SingleApp  DispFrames     RF  0.084215

# %%
group = data.groupby(["período"])['nmae'].agg(['mean', 'std']).reset_index()

# %%
group['std'] = round(100*group['std'], 0)
group['mean'] = round(100*group['mean'], 0)

# %%
group
# Out:
#    período  mean  std
# 0        8   9.0  2.0
# 1       16  11.0  2.0
# 2       32  12.0  3.0
# 3       64  12.0  1.0
# 4      128  13.0  6.0
# 5      256  15.0  7.0

# %%
new_data = pd.DataFrame({'período': [1], 'mean': [12], 'std': [2]})

total_table = pd.concat([group, new_data], ignore_index=True)

# %%
total_table.set_index('período', inplace=True)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 8))
sns.boxplot(x='período', y='nmae', data=data)

plt.xlabel("Período", fontsize=12)
plt.ylabel("NMAE", fontsize=12)
plt.title("NMAE Janelas com Distribuições TPTT por período", fontsize=14)
plt.xticks(rotation=45)
plt.ylim((0, 0.25))

plt.tight_layout()

plt.show()

# %%
group_by_method = data.groupby(["período", "método"])['nmae'].agg(['mean', 'std']).reset_index()

# %%
group_by_method['std'] = round(100*group_by_method['std'], 0)
group_by_method['mean'] = round(100*group_by_method['mean'], 0)

# %%
group_by_method
# Out:
#     período método  mean  std
# 0         8     RF  10.0  2.0
# 1         8     RT   9.0  2.0
# 2        16     RF  11.0  2.0
# 3        16     RT  11.0  2.0
# 4        32     RF  12.0  3.0
# 5        32     RT  12.0  3.0
# 6        64     RF  12.0  1.0
# 7        64     RT  12.0  1.0
# 8       128     RF  13.0  5.0
# 9       128     RT  13.0  5.0
# 10      256     RF  16.0  6.0
# 11      256     RT  15.0  8.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

y_limits = (0, 0.25)

sns.boxplot(x='período', y='nmae', data=data[data['método'] == 'RT'],
            color="lightblue", boxprops=dict(alpha=0.7), fliersize=5, ax=axes[0])
axes[0].set_ylim(y_limits)
axes[0].set_xlabel("Período", fontsize=12)
axes[0].set_ylabel("NMAE", fontsize=12)
axes[0].set_title("NMAE por Período e Método (RT)", fontsize=14)
axes[0].tick_params(axis='x', rotation=45, labelsize=10)
axes[0].tick_params(axis='y', labelsize=10)

sns.boxplot(x='período', y='nmae', data=data[data['método'] == 'RF'],
            color="lightcoral", boxprops=dict(alpha=0.7), fliersize=5, ax=axes[1])
axes[1].set_ylim(y_limits)
axes[1].set_xlabel("Período", fontsize=12)
axes[1].set_ylabel("NMAE", fontsize=12)
axes[1].set_title("NMAE por Período e Método (RF)", fontsize=14)
axes[1].tick_params(axis='x', rotation=45, labelsize=10)
axes[1].tick_params(axis='y', labelsize=10)

fig.suptitle("Resultados em Janelas com Distribuições TPTT", fontsize=16)

plt.tight_layout(pad=3.0)

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

y_limits = (0, 0.25)

sns.boxplot(x='período', y='nmae', data=data[data['carga'] == 'PeriodicLoad'],
            color="lightblue", boxprops=dict(alpha=0.7), fliersize=5, ax=axes[0])
axes[0].set_ylim(y_limits)
axes[0].set_xlabel("Período", fontsize=12)
axes[0].set_ylabel("NMAE", fontsize=12)
axes[0].set_title("NMAE por Período e Carga (Periódica)", fontsize=14)
axes[0].tick_params(axis='x', rotation=45, labelsize=10)
axes[0].tick_params(axis='y', labelsize=10)

sns.boxplot(x='período', y='nmae', data=data[data['carga'] == 'FlashcrowdLoad'],
            color="lightcoral", boxprops=dict(alpha=0.7), fliersize=5, ax=axes[1])
axes[1].set_ylim(y_limits)
axes[1].set_xlabel("Período", fontsize=12)
axes[1].set_ylabel("NMAE", fontsize=12)
axes[1].set_title("NMAE por Período e Carga (Aleatória)", fontsize=14)
axes[1].tick_params(axis='x', rotation=45, labelsize=10)
axes[1].tick_params(axis='y', labelsize=10)

fig.suptitle("Resultados em Janelas com Distribuições FS TPTT por Carga", fontsize=16)

plt.tight_layout(pad=3.0)

plt.show()
